# %% [markdown]
# ### Import pandas library for data manipulation

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read the dataset into the notebook

# %%
pd.read_csv('assignment.csv')
# Out:
#      Unnamed: 0 IMBD title ID               Original titlÊ  Release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          Genrë¨ Duration       Country Content Rating  \
# ...

# %% [markdown]
# ### Assign a name to the dataset

# %%
df = pd.read_csv('assignment.csv')

# %%
df.head(3)
# Out:
#    Unnamed: 0 IMBD title ID            Original titlÊ  Release year  \
# 0           0     tt0111161  The Shawshank Redemption    1995-02-10
# 1           1     tt0068646             The Godfather    09 21 1972
# 2           2     tt0468569           The Dark Knight   23 -07-2008
#
#                  Genrë¨ Duration Country Content Rating              Director  \
# 0                 Drama      142     USA              R        Frank Darabont
# 1          Crime, Drama      175     USA              R  Francis Ford Coppola
# 2  Action, Crime, Drama      152      US          PG-13     Christopher Nolan
#
#    Unnamed: 8        Income     Votes  Score
# 0         NaN    $ 28815245  2.278.845   9.3
# 1         NaN   $ 246120974  1.572.674   9.2
# 2         NaN  $ 1005455211  2.241.615    9.

# %% [markdown]
# ### Run summary view of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      101 non-null    int64
#  1   IMBD title ID   100 non-null    object
#  2   Original titlÊ  100 non-null    object
#  3   Release year    100 non-null    object
#  4   Genrë¨          100 non-null    object
#  5   Duration        99 non-null     object
#  6   Country         100 non-null    object
#  7   Content Rating  77 non-null     object
#  8   Director        100 non-null    object
#  9   Unnamed: 8      0 non-null      float64
#  10  Income          100 non-null    object
#  11   Votes          100 non-null    object
#  12  Score           100 non-null    object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 10.4+ KB

# %%
df.shape
# Out:
# (101, 13)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'IMBD title ID', 'Original titlÊ', 'Release year',
#        'Genrë¨', 'Duration', 'Country', 'Content Rating', 'Director',
#        'Unnamed: 8', 'Income', ' Votes ', 'Score'],
#       dtype='object')

# %% [markdown]
# To transform the columns I'll do the following in no particular oder
# - Rename columns
# - Drop unwanted columns
# - Convert each column to the correct data type
# - Fill any NaN cells

# %% [markdown]
# ### Rename & transform the columns for ease of use

# %% [markdown]
# #### Rename columns

# %%
df = df.rename(columns={'Unnamed: 0': 'id', 'Original titlÊ': 'title', 'Genrë¨': 'genre', 'Release year': 'year', 'Content Rating': 'rating', ' Votes ': 'votes'})

# %%
df.head(3)
# Out:
#    id IMBD title ID                     title          year  \
# 0   0     tt0111161  The Shawshank Redemption    1995-02-10
# 1   1     tt0068646             The Godfather    09 21 1972
# 2   2     tt0468569           The Dark Knight   23 -07-2008
#
#                   genre Duration Country rating              Director  \
# 0                 Drama      142     USA      R        Frank Darabont
# 1          Crime, Drama      175     USA      R  Francis Ford Coppola
# 2  Action, Crime, Drama      152      US  PG-13     Christopher Nolan
#
#    Unnamed: 8        Income      votes Score
# 0         NaN    $ 28815245  2.278.845   9.3
# 1         NaN   $ 246120974  1.572.674   9.2
# 2         NaN  $ 1005455211  2.241.615    9.

# %% [markdown]
# #### Transform the titles to lower case

# %%
df.columns = df.columns.str.lower()

# %%
df.head(6)
# Out:
#    id imbd title id                                          title  \
# 0   0     tt0111161                       The Shawshank Redemption
# 1   1     tt0068646                                  The Godfather
# 2   2     tt0468569                                The Dark Knight
# 3   3     tt0071562                         The Godfather: Part II
# 4   4     tt0110912                                   Pulp Fiction
# 5   5     tt0167260  The Lord of the Rings: The Return of the King
#
#            year                     genre duration      country rating  \
# 0    1995-02-10                     Drama      142          USA      R
# 1    09 21 1972              Crime, Drama      175          USA      R
# 2   23 -07-2008      Action, Crime, Drama      152           US  PG-13
# 3    1975-09-25              Crime, Drama      220          USA      R
# 4    1994-10-28              Crime, Drama                   USA      R
# ...

# %% [markdown]
# ### Drop unwanted columns

# %%
df.drop(['id', 'imbd title id', 'unnamed: 8'], axis = 1, inplace = True)

# %%
df.head(3)
# Out:
#                       title          year                 genre duration  \
# 0  The Shawshank Redemption    1995-02-10                 Drama      142
# 1             The Godfather    09 21 1972          Crime, Drama      175
# 2           The Dark Knight   23 -07-2008  Action, Crime, Drama      152
#
#   country rating              director        income      votes score
# 0     USA      R        Frank Darabont    $ 28815245  2.278.845   9.3
# 1     USA      R  Francis Ford Coppola   $ 246120974  1.572.674   9.2
# 2      US  PG-13     Christopher Nolan  $ 1005455211  2.241.615    9.

# %% [markdown]
# #### Transform the year column

# %%
pd.to_datetime(df['year'], errors = 'coerce')

df['year'] = pd.to_datetime(df['year'], errors = 'coerce')
df
# Out:
# C:\Users\Tracy\AppData\Local\Temp\ipykernel_8844\1923964493.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   pd.to_datetime(df['year'], errors = 'coerce')
# C:\Users\Tracy\AppData\Local\Temp\ipykernel_8844\1923964493.py:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['year'] = pd.to_datetime(df['year'], errors = 'coerce')
#                            title       year                       genre  \
# 0       The Shawshank Redemption 1995-02-10                       Drama
# 1                  The Godfather 1972-09-21                Crime, Drama
# 2                The Dark Knight 2008-07-23        Action, Crime, Drama
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     100 non-null    object
#  1   year      97 non-null     datetime64[ns]
#  2   genre     100 non-null    object
#  3   duration  99 non-null     object
#  4   country   100 non-null    object
#  5   rating    77 non-null     object
#  6   director  100 non-null    object
#  7   income    100 non-null    object
#  8   votes     100 non-null    object
#  9   score     100 non-null    object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 8.0+ KB

# %%
df[df.year.isnull()]
# Out:
#            title year             genre duration country rating  \
# 13           NaN  NaT               NaN      NaN     NaN    NaN
# 70  Sunset Blvd.  NaT  Drama, Film-Noir      110     USA    NaN
# 83      Scarface  NaT      Crime, Drama      170     USA      R
# 84   Taxi Driver  NaT      Crime, Drama      114     USA      R
#
#            director      income    votes score
# 13              NaN         NaN      NaN   NaN
# 70     Billy Wilder    $ 299645  195.789   8.0
# 83   Brian De Palma  $ 66023585  721.343   7.8
# 84  Martin Scorsese  $ 28441292  703.264   7.7

# %%
df.loc[70, 'year'] = '1950-08-10'
df.loc[83, 'year'] = '1983-12-09'
df.loc[84, 'year'] = '1976-02-08'

df
# Out:
#                            title       year                       genre  \
# 0       The Shawshank Redemption 1995-02-10                       Drama
# 1                  The Godfather 1972-09-21                Crime, Drama
# 2                The Dark Knight 2008-07-23        Action, Crime, Drama
# 3         The Godfather: Part II 1975-09-25                Crime, Drama
# 4                   Pulp Fiction 1994-10-28                Crime, Drama
# ..                           ...        ...                         ...
# 96                     The Sting 1974-03-21        Comedy, Crime, Drama
# 97                      Das Boot 1982-03-18  Adventure, Drama, Thriller
# 98   Per qualche dollaro in piÃ¹ 1965-12-20                     Western
# 99       Jodaeiye Nader az Simin 2011-10-21                       Drama
# 100          Singin' in the Rain 1953-02-05    Comedy, Musical, Romance
#
#     duration       country rating              director         income  \
# ...

# %%
df.drop(13, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     100 non-null    object
#  1   year      100 non-null    datetime64[ns]
#  2   genre     100 non-null    object
#  3   duration  99 non-null     object
#  4   country   100 non-null    object
#  5   rating    77 non-null     object
#  6   director  100 non-null    object
#  7   income    100 non-null    object
#  8   votes     100 non-null    object
#  9   score     100 non-null    object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 8.6+ KB

# %% [markdown]
# ### Transform the duration column

# %% [markdown]
# #### Replace the Null value in the duration column

# %%
df[df.duration.isnull()]
# Out:
#          title       year           genre duration country rating  \
# 14  The Matrix 1999-05-07  Action, Sci-Fi      NaN     USA      R
#
#                            director       income      votes  score
# 14  Lana Wachowski, Lilly Wachowski  $ 465718588  1.632.315  ++8.7

# %%
df.loc[14, 'duration'] = '136'

df
# Out:
#                            title       year                       genre  \
# 0       The Shawshank Redemption 1995-02-10                       Drama
# 1                  The Godfather 1972-09-21                Crime, Drama
# 2                The Dark Knight 2008-07-23        Action, Crime, Drama
# 3         The Godfather: Part II 1975-09-25                Crime, Drama
# 4                   Pulp Fiction 1994-10-28                Crime, Drama
# ..                           ...        ...                         ...
# 96                     The Sting 1974-03-21        Comedy, Crime, Drama
# 97                      Das Boot 1982-03-18  Adventure, Drama, Thriller
# 98   Per qualche dollaro in piÃ¹ 1965-12-20                     Western
# 99       Jodaeiye Nader az Simin 2011-10-21                       Drama
# 100          Singin' in the Rain 1953-02-05    Comedy, Musical, Romance
#
#     duration       country rating              director         income  \
# ...

# %% [markdown]
# #### Transform the duration column, note the cells with incorrect datatypes and transform them.

# %%
pd.to_numeric(df['duration'], errors = 'coerce')
df['duration'] = pd.to_numeric(df['duration'], errors = 'coerce')

df
# Out:
#                            title       year                       genre  \
# 0       The Shawshank Redemption 1995-02-10                       Drama
# 1                  The Godfather 1972-09-21                Crime, Drama
# 2                The Dark Knight 2008-07-23        Action, Crime, Drama
# 3         The Godfather: Part II 1975-09-25                Crime, Drama
# 4                   Pulp Fiction 1994-10-28                Crime, Drama
# ..                           ...        ...                         ...
# 96                     The Sting 1974-03-21        Comedy, Crime, Drama
# 97                      Das Boot 1982-03-18  Adventure, Drama, Thriller
# 98   Per qualche dollaro in piÃ¹ 1965-12-20                     Western
# 99       Jodaeiye Nader az Simin 2011-10-21                       Drama
# 100          Singin' in the Rain 1953-02-05    Comedy, Musical, Romance
#
#      duration       country rating              director         income  \
# ...

# %% [markdown]
# #### Check how many null values are in the duration column

# %%
df[df.duration.isnull()]
# Out:
#                                                 title       year  \
# 4                                        Pulp Fiction 1994-10-28
# 6                                    Schindler's List 1994-03-11
# 11  The Lord of the Rings: The Fellowship of the Ring 2002-01-18
# 16     Star Wars: Episode V - The Empire Strikes Back 1980-09-19
# 18                    One Flew Over the Cuckoo's Nest 1976-11-18
#
#                          genre  duration      country rating  \
# 4                 Crime, Drama       NaN          USA      R
# 6    Biography, Drama, History       NaN          USA      R
# 11    Action, Adventure, Drama       NaN  New Zesland  PG-13
# 16  Action, Adventure, Fantasy       NaN          USA     PG
# 18                       Drama       NaN          USA      R
#
#              director       income      votes   score
# 4   Quentin Tarantino  $ 222831817  1.780.147    8,9f
# 6    Steven Spielberg  $ 322287794  1.183.248     8.9
# ...

# %% [markdown]
# #### Replace the Null values

# %%
df.loc[4, 'duration'] = '154.0'
df.loc[6, 'duration'] = '195.0'
df.loc[11, 'duration'] = '178.0'
df.loc[16, 'duration'] = '124.0'
df.loc[18, 'duration'] = '133.0'

df
# Out:
#                            title       year                       genre  \
# 0       The Shawshank Redemption 1995-02-10                       Drama
# 1                  The Godfather 1972-09-21                Crime, Drama
# 2                The Dark Knight 2008-07-23        Action, Crime, Drama
# 3         The Godfather: Part II 1975-09-25                Crime, Drama
# 4                   Pulp Fiction 1994-10-28                Crime, Drama
# ..                           ...        ...                         ...
# 96                     The Sting 1974-03-21        Comedy, Crime, Drama
# 97                      Das Boot 1982-03-18  Adventure, Drama, Thriller
# 98   Per qualche dollaro in piÃ¹ 1965-12-20                     Western
# 99       Jodaeiye Nader az Simin 2011-10-21                       Drama
# 100          Singin' in the Rain 1953-02-05    Comedy, Musical, Romance
#
#     duration       country rating              director         income  \
# ...

# %% [markdown]
# #### Check the transformation was done right & completely

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     100 non-null    object
#  1   year      100 non-null    datetime64[ns]
#  2   genre     100 non-null    object
#  3   duration  100 non-null    object
#  4   country   100 non-null    object
#  5   rating    77 non-null     object
#  6   director  100 non-null    object
#  7   income    100 non-null    object
#  8   votes     100 non-null    object
#  9   score     100 non-null    object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 12.7+ KB

# %% [markdown]
# #### Convert the duration column to a numeric column

# %%
pd.to_numeric(df['duration'], errors = 'coerce')
df['duration'] = pd.to_numeric(df['duration'], errors = 'coerce')

df
# Out:
#                            title       year                       genre  \
# 0       The Shawshank Redemption 1995-02-10                       Drama
# 1                  The Godfather 1972-09-21                Crime, Drama
# 2                The Dark Knight 2008-07-23        Action, Crime, Drama
# 3         The Godfather: Part II 1975-09-25                Crime, Drama
# 4                   Pulp Fiction 1994-10-28                Crime, Drama
# ..                           ...        ...                         ...
# 96                     The Sting 1974-03-21        Comedy, Crime, Drama
# 97                      Das Boot 1982-03-18  Adventure, Drama, Thriller
# 98   Per qualche dollaro in piÃ¹ 1965-12-20                     Western
# 99       Jodaeiye Nader az Simin 2011-10-21                       Drama
# 100          Singin' in the Rain 1953-02-05    Comedy, Musical, Romance
#
#      duration       country rating              director         income  \
# ...

# %% [markdown]
# #### Check the transformation was done right & completely

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     100 non-null    object
#  1   year      100 non-null    datetime64[ns]
#  2   genre     100 non-null    object
#  3   duration  100 non-null    float64
#  4   country   100 non-null    object
#  5   rating    77 non-null     object
#  6   director  100 non-null    object
#  7   income    100 non-null    object
#  8   votes     100 non-null    object
#  9   score     100 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 12.7+ KB

# %% [markdown]
# ### Transform the country column

# %% [markdown]
# #### Check for the unique values of the country column

# %%
df.country.unique()
# Out:
# array(['USA', 'US', 'New Zealand', 'UK', 'New Zesland', 'Italy',
#        'New Zeland', 'US.', 'Brazil', 'Japan', 'Italy1', 'South Korea',
#        'France', 'Germany', 'India', 'Denmark', 'West Germany', 'Iran'],
#       dtype=object)

# %% [markdown]
# #### Transform the values so they're all the right countries

# %%
df['country'].replace(['US', 'New Zesland', 'New Zeland', 'US.', 'Italy1', 'West Germany'], ['USA', 'New Zealand', 'New Zealand', 'USA', 'Italy', 'Germany'])
df.country = df['country'].replace(['US', 'New Zesland', 'New Zeland', 'US.', 'Italy1', 'West Germany'], ['USA', 'New Zealand', 'New Zealand', 'USA', 'Italy', 'Germany'])

# %% [markdown]
# #### Check for the unique values of the country column

# %%
df.country.unique()
# Out:
# array(['USA', 'New Zealand', 'UK', 'Italy', 'Brazil', 'Japan',
#        'South Korea', 'France', 'Germany', 'India', 'Denmark', 'Iran'],
#       dtype=object)

# %%
df.head()
# Out:
#                       title       year                 genre  duration  \
# 0  The Shawshank Redemption 1995-02-10                 Drama     142.0
# 1             The Godfather 1972-09-21          Crime, Drama     175.0
# 2           The Dark Knight 2008-07-23  Action, Crime, Drama     152.0
# 3    The Godfather: Part II 1975-09-25          Crime, Drama     220.0
# 4              Pulp Fiction 1994-10-28          Crime, Drama     154.0
#
#   country rating              director         income      votes score
# 0     USA      R        Frank Darabont     $ 28815245  2.278.845   9.3
# 1     USA      R  Francis Ford Coppola    $ 246120974  1.572.674   9.2
# 2     USA  PG-13     Christopher Nolan   $ 1005455211  2.241.615    9.
# 3     USA      R  Francis Ford Coppola  $ 4o8,035,783  1.098.714  9,.0
# 4     USA      R     Quentin Tarantino    $ 222831817  1.780.147  8,9f

# %% [markdown]
# ### Transform rating column

# %% [markdown]
# #### Check for the Null cells

# %%
df[df.rating.isnull()]
# Out:
#                                  title       year  \
# 27                    La vita B9 bella 1997-12-20
# 28                        Gisaengchung 2019-11-07
# 36                               LÃ©on 1995-04-07
# 40                               Joker 2019-10-03
# 41                        Intouchables 2012-02-24
# 47                      Hotaru no haka 2015-10-11
# 48               Nuovo Cinema Paradiso 1988-11-17
# 56              Avengers: Infinity War 2018-04-25
# 58                   Avengers: Endgame 2019-04-24
# 62                         Rear Window 1955-04-14
# 63                                Coco 2017-12-28
# 65   Spider-Man: Into the Spider-Verse 2018-12-25
# 66                            3 Idiots 2009-12-25
# 69                  The Great Dictator 1945-06-25
# 70                        Sunset Blvd. 1950-08-10
# 81                  A Clockwork Orange 1972-09-07
# 86                   Full Metal Jacket 1987-10-09
# 89                        Citizen Kane 1948-11-25
# ...

# %% [markdown]
# #### Replace Null values

# %%
df.loc[27, 'rating'] = 'PG-13'
df.loc[28, 'rating'] = 'R'
df.loc[36, 'rating'] = 'R'
df.loc[40, 'rating'] = 'R'
df.loc[41, 'rating'] = 'R'
df.loc[48, 'rating'] = 'PG'
df.loc[56, 'rating'] = 'PG-13'
df.loc[58, 'rating'] = 'PG-13'
df.loc[62, 'rating'] = 'PG'
df.loc[63, 'rating'] = 'PG'
df.loc[65, 'rating'] = 'PG'
df.loc[66, 'rating'] = 'PG-13'
df.loc[69, 'rating'] = 'G'
df.loc[70, 'rating'] = 'PG'
df.loc[81, 'rating'] = '18'
df.loc[86, 'rating'] = '16+'
df.loc[89, 'rating'] = 'PG'
df.loc[90, 'rating'] = 'R'
df.loc[92, 'rating'] = 'PG'
df.loc[93, 'rating'] = 'PG'
df.loc[98, 'rating'] = 'R'
df.loc[100, 'rating'] = 'G'

df
# Out:
#                            title       year                       genre  \
# 0       The Shawshank Redemption 1995-02-10                       Drama
# 1                  The Godfather 1972-09-21                Crime, Drama
# 2                The Dark Knight 2008-07-23        Action, Crime, Drama
# 3         The Godfather: Part II 1975-09-25                Crime, Drama
# 4                   Pulp Fiction 1994-10-28                Crime, Drama
# ..                           ...        ...                         ...
# 96                     The Sting 1974-03-21        Comedy, Crime, Drama
# 97                      Das Boot 1982-03-18  Adventure, Drama, Thriller
# 98   Per qualche dollaro in piÃ¹ 1965-12-20                     Western
# 99       Jodaeiye Nader az Simin 2011-10-21                       Drama
# 100          Singin' in the Rain 1953-02-05    Comedy, Musical, Romance
#
#      duration  country rating              director         income      votes  \
# ...

# %% [markdown]
# #### Check for the Null cells

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     100 non-null    object
#  1   year      100 non-null    datetime64[ns]
#  2   genre     100 non-null    object
#  3   duration  100 non-null    float64
#  4   country   100 non-null    object
#  5   rating    99 non-null     object
#  6   director  100 non-null    object
#  7   income    100 non-null    object
#  8   votes     100 non-null    object
#  9   score     100 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 12.7+ KB

# %% [markdown]
# ### Transform the income column

# %% [markdown]
# #### Get rid of the '$' & ','

# %%
df.income = df['income'].str.replace(',', '')
df.income = df['income'].str.replace('$', '', regex = True)
df
# Out:
#                            title       year                       genre  \
# 0       The Shawshank Redemption 1995-02-10                       Drama
# 1                  The Godfather 1972-09-21                Crime, Drama
# 2                The Dark Knight 2008-07-23        Action, Crime, Drama
# 3         The Godfather: Part II 1975-09-25                Crime, Drama
# 4                   Pulp Fiction 1994-10-28                Crime, Drama
# ..                           ...        ...                         ...
# 96                     The Sting 1974-03-21        Comedy, Crime, Drama
# 97                      Das Boot 1982-03-18  Adventure, Drama, Thriller
# 98   Per qualche dollaro in piÃ¹ 1965-12-20                     Western
# 99       Jodaeiye Nader az Simin 2011-10-21                       Drama
# 100          Singin' in the Rain 1953-02-05    Comedy, Musical, Romance
#
#      duration  country rating              director       income      votes  \
# ...

# %% [markdown]
# #### Correct base 10: ' 4o8035783'

# %%
df.loc[3, 'income'] = '408035783'
df.head()
# Out:
#                       title       year                 genre  duration  \
# 0  The Shawshank Redemption 1995-02-10                 Drama     142.0
# 1             The Godfather 1972-09-21          Crime, Drama     175.0
# 2           The Dark Knight 2008-07-23  Action, Crime, Drama     152.0
# 3    The Godfather: Part II 1975-09-25          Crime, Drama     220.0
# 4              Pulp Fiction 1994-10-28          Crime, Drama     154.0
#
#   country rating              director       income      votes score
# 0     USA      R        Frank Darabont     28815245  2.278.845   9.3
# 1     USA      R  Francis Ford Coppola    246120974  1.572.674   9.2
# 2     USA  PG-13     Christopher Nolan   1005455211  2.241.615    9.
# 3     USA      R  Francis Ford Coppola    408035783  1.098.714  9,.0
# 4     USA      R     Quentin Tarantino    222831817  1.780.147  8,9f

# %% [markdown]
# #### Check no of Null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     100 non-null    object
#  1   year      100 non-null    datetime64[ns]
#  2   genre     100 non-null    object
#  3   duration  100 non-null    float64
#  4   country   100 non-null    object
#  5   rating    99 non-null     object
#  6   director  100 non-null    object
#  7   income    100 non-null    object
#  8   votes     100 non-null    object
#  9   score     100 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 12.7+ KB

# %%
pd.to_numeric(df['income'])
df['income'] = pd.to_numeric(df['income'])

df
# Out:
#                            title       year                       genre  \
# 0       The Shawshank Redemption 1995-02-10                       Drama
# 1                  The Godfather 1972-09-21                Crime, Drama
# 2                The Dark Knight 2008-07-23        Action, Crime, Drama
# 3         The Godfather: Part II 1975-09-25                Crime, Drama
# 4                   Pulp Fiction 1994-10-28                Crime, Drama
# ..                           ...        ...                         ...
# 96                     The Sting 1974-03-21        Comedy, Crime, Drama
# 97                      Das Boot 1982-03-18  Adventure, Drama, Thriller
# 98   Per qualche dollaro in piÃ¹ 1965-12-20                     Western
# 99       Jodaeiye Nader az Simin 2011-10-21                       Drama
# 100          Singin' in the Rain 1953-02-05    Comedy, Musical, Romance
#
#      duration  country rating              director      income      votes  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     100 non-null    object
#  1   year      100 non-null    datetime64[ns]
#  2   genre     100 non-null    object
#  3   duration  100 non-null    float64
#  4   country   100 non-null    object
#  5   rating    99 non-null     object
#  6   director  100 non-null    object
#  7   income    100 non-null    int64
#  8   votes     100 non-null    object
#  9   score     100 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 12.7+ KB

# %% [markdown]
# ### Transform the votes column

# %%
df.votes = df['votes'].str.replace('.', '', regex = True)
df.head()
# Out:
#                       title       year                 genre  duration  \
# 0  The Shawshank Redemption 1995-02-10                 Drama     142.0
# 1             The Godfather 1972-09-21          Crime, Drama     175.0
# 2           The Dark Knight 2008-07-23  Action, Crime, Drama     152.0
# 3    The Godfather: Part II 1975-09-25          Crime, Drama     220.0
# 4              Pulp Fiction 1994-10-28          Crime, Drama     154.0
#
#   country rating              director      income    votes score
# 0     USA      R        Frank Darabont    28815245  2278845   9.3
# 1     USA      R  Francis Ford Coppola   246120974  1572674   9.2
# 2     USA  PG-13     Christopher Nolan  1005455211  2241615    9.
# 3     USA      R  Francis Ford Coppola   408035783  1098714  9,.0
# 4     USA      R     Quentin Tarantino   222831817  1780147  8,9f

# %% [markdown]
# #### Convert the datatype to integer

# %%
pd.to_numeric(df['votes'])
df['votes'] = pd.to_numeric(df['votes'])

df.head()
# Out:
#                       title       year                 genre  duration  \
# 0  The Shawshank Redemption 1995-02-10                 Drama     142.0
# 1             The Godfather 1972-09-21          Crime, Drama     175.0
# 2           The Dark Knight 2008-07-23  Action, Crime, Drama     152.0
# 3    The Godfather: Part II 1975-09-25          Crime, Drama     220.0
# 4              Pulp Fiction 1994-10-28          Crime, Drama     154.0
#
#   country rating              director      income    votes score
# 0     USA      R        Frank Darabont    28815245  2278845   9.3
# 1     USA      R  Francis Ford Coppola   246120974  1572674   9.2
# 2     USA  PG-13     Christopher Nolan  1005455211  2241615    9.
# 3     USA      R  Francis Ford Coppola   408035783  1098714  9,.0
# 4     USA      R     Quentin Tarantino   222831817  1780147  8,9f

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     100 non-null    object
#  1   year      100 non-null    datetime64[ns]
#  2   genre     100 non-null    object
#  3   duration  100 non-null    float64
#  4   country   100 non-null    object
#  5   rating    99 non-null     object
#  6   director  100 non-null    object
#  7   income    100 non-null    int64
#  8   votes     100 non-null    int64
#  9   score     100 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(6)
# memory usage: 12.7+ KB

# %% [markdown]
# ### Transform score column

# %%
df['score'] = pd.to_numeric(df['score'], errors = 'coerce')
df['score'].head()
# Out:
# 0    9.3
# 1    9.2
# 2    9.0
# 3    NaN
# 4    NaN
# Name: score, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     100 non-null    object
#  1   year      100 non-null    datetime64[ns]
#  2   genre     100 non-null    object
#  3   duration  100 non-null    float64
#  4   country   100 non-null    object
#  5   rating    99 non-null     object
#  6   director  100 non-null    object
#  7   income    100 non-null    int64
#  8   votes     100 non-null    int64
#  9   score     92 non-null     float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(5)
# memory usage: 12.7+ KB

# %%
df[df.score.isnull()]
# Out:
#                                              title       year  \
# 3                           The Godfather: Part II 1975-09-25
# 4                                     Pulp Fiction 1994-10-28
# 8                                        Inception 2010-09-24
# 10                                    Forrest Gump 1994-10-06
# 14                                      The Matrix 1999-05-07
# 15           The Lord of the Rings: The Two Towers 2003-01-16
# 16  Star Wars: Episode V - The Empire Strikes Back 1980-09-19
# 21                        The Silence of the Lambs 1991-03-05
#
#                          genre  duration      country rating  \
# 3                 Crime, Drama     220.0          USA      R
# 4                 Crime, Drama     154.0          USA      R
# 8    Action, Adventure, Sci-Fi     148.0          USA  PG-13
# 10              Drama, Romance     142.0          USA  PG-13
# 14              Action, Sci-Fi     136.0          USA      R
# ...

# %%
df.loc[3, 'score'] = '9.0'
df.loc[4, 'score'] = '8.9'
df.loc[8, 'score'] = '8.8'
df.loc[10, 'score'] = '8.8'
df.loc[14, 'score'] = '8.7'
df.loc[15, 'score'] = '8.8'
df.loc[16, 'score'] = '8.7'
df.loc[21, 'score'] = '8.6'
df
# Out:
#                            title       year                       genre  \
# 0       The Shawshank Redemption 1995-02-10                       Drama
# 1                  The Godfather 1972-09-21                Crime, Drama
# 2                The Dark Knight 2008-07-23        Action, Crime, Drama
# 3         The Godfather: Part II 1975-09-25                Crime, Drama
# 4                   Pulp Fiction 1994-10-28                Crime, Drama
# ..                           ...        ...                         ...
# 96                     The Sting 1974-03-21        Comedy, Crime, Drama
# 97                      Das Boot 1982-03-18  Adventure, Drama, Thriller
# 98   Per qualche dollaro in piÃ¹ 1965-12-20                     Western
# 99       Jodaeiye Nader az Simin 2011-10-21                       Drama
# 100          Singin' in the Rain 1953-02-05    Comedy, Musical, Romance
#
#      duration  country rating              director      income    votes score
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     100 non-null    object
#  1   year      100 non-null    datetime64[ns]
#  2   genre     100 non-null    object
#  3   duration  100 non-null    float64
#  4   country   100 non-null    object
#  5   rating    99 non-null     object
#  6   director  100 non-null    object
#  7   income    100 non-null    int64
#  8   votes     100 non-null    int64
#  9   score     100 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(6)
# memory usage: 12.7+ KB

# %%
df['score'] = pd.to_numeric(df['score'])
df['score'].head()
# Out:
# 0    9.3
# 1    9.2
# 2    9.0
# 3    9.0
# 4    8.9
# Name: score, dtype: float64

# %%
df.dtypes
# Out:
# title               object
# year        datetime64[ns]
# genre               object
# duration           float64
# country             object
# rating              object
# director            object
# income               int64
# votes                int64
# score              float64
# dtype: object

# %%
df
# Out:
#                            title       year                       genre  \
# 0       The Shawshank Redemption 1995-02-10                       Drama
# 1                  The Godfather 1972-09-21                Crime, Drama
# 2                The Dark Knight 2008-07-23        Action, Crime, Drama
# 3         The Godfather: Part II 1975-09-25                Crime, Drama
# 4                   Pulp Fiction 1994-10-28                Crime, Drama
# ..                           ...        ...                         ...
# 96                     The Sting 1974-03-21        Comedy, Crime, Drama
# 97                      Das Boot 1982-03-18  Adventure, Drama, Thriller
# 98   Per qualche dollaro in piÃ¹ 1965-12-20                     Western
# 99       Jodaeiye Nader az Simin 2011-10-21                       Drama
# 100          Singin' in the Rain 1953-02-05    Comedy, Musical, Romance
#
#      duration  country rating              director      income    votes  \
# ...

# %% [markdown]
# #### Clean some titles I noticed earlier were wrong

# %%
df.loc[27, 'title'] = 'La vita è bella'
df.loc[36, 'title'] = 'Léon: The Professional'
df.loc[98, 'title'] = 'Per qualche dollaro in più'

# %%
df
# Out:
#                           title       year                       genre  \
# 0      The Shawshank Redemption 1995-02-10                       Drama
# 1                 The Godfather 1972-09-21                Crime, Drama
# 2               The Dark Knight 2008-07-23        Action, Crime, Drama
# 3        The Godfather: Part II 1975-09-25                Crime, Drama
# 4                  Pulp Fiction 1994-10-28                Crime, Drama
# ..                          ...        ...                         ...
# 96                    The Sting 1974-03-21        Comedy, Crime, Drama
# 97                     Das Boot 1982-03-18  Adventure, Drama, Thriller
# 98   Per qualche dollaro in più 1965-12-20                     Western
# 99      Jodaeiye Nader az Simin 2011-10-21                       Drama
# 100         Singin' in the Rain 1953-02-05    Comedy, Musical, Romance
#
#      duration  country rating              director      income    votes  \
# ...

# %%
df.dtypes
# Out:
# title               object
# year        datetime64[ns]
# genre               object
# duration           float64
# country             object
# rating              object
# director            object
# income               int64
# votes                int64
# score              float64
# dtype: object

# %%
df.to_csv('python_wrangling')
